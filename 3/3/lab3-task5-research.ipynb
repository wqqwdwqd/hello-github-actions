# %% [markdown]
# # Исследование для Задания 5
# ## Изучение статей и документации

# %% [markdown]
# ### Статья: "Publish a Notebook as a Dashboard Using the Layout Builder"
#
# **Основные шаги:**
# 1. Создание интерактивных виджетов
# 2. Использование Layout Builder для компоновки
# 3. Публикация дашборда
# 4. Настройка совместного доступа
#
# **Ключевые концепции:**
# - Интерактивные элементы управления
# - Реактивное программирование
# - Компоновка компонентов

# %% [markdown]
# ### Статья: "Build Dashboard"
#
# **Основные компоненты:**
# - Виджеты (sliders, dropdowns, buttons)
# - Графики и визуализации
# - Вкладки и layout
# - Темы оформления
#
# **Технологии:**
# - Panel для создания интерфейса
# - Plotly/HvPlot для графиков
# - Pandas для работы с данными

# %% [markdown]
# ### Статья: "How to Deploy a Panel Visualization Dashboard to GitHub Pages"
#
# **Шаги для публикации:**
# 1. Создание GitHub репозитория
# 2. Подготовка файлов приложения
# 3. Настройка GitHub Pages
# 4. Деплой приложения
#
# **Требования:**
# - Статические HTML файлы
# - Правильная структура проекта
# - Настройка ветки gh-pages

# %%
# Создаём README для заданий 5
readme_content = """
# Задание 5 - Создание приложений

## Созданные приложения:

### 1. Panel App
- Файл: `lab3-task5-panel.ipynb`
- Экспорт: `src/panel_dashboard.html`
- Особенности: интерактивные графики, фильтры данных

### 2. Voilà App  
- Файл: `lab3-task5-voila.ipynb`
- Особенности: интерактивная визуализация продаж

### 3. Исследования
- Файл: `lab3-task5-research.ipynb`
- Содержание: изучение статей по созданию дашбордов

## Используемые технологии:
- Panel 1.0+
- Voilà 0.4+
- Plotly 5.0+
- Pandas 2.0+
"""

with open('src/README_task5.md', 'w', encoding='utf-8') as f:
    f.write(readme_content)

print("README для задания 5 создан!")
# Out:
# README для задания 5 создан!
