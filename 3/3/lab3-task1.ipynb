# %% [markdown]
# Лабораторная работа 3. Задание 1

# %%
# !gawk '{print $1}' src/myfile
# Out:
# This
# This
# This
# This

# %%
# !gsed 's/Яшин/Кашин/' src/list_students.txt
# Out:
# Асташко Иван ПИ 1 6
# Бузун Евгений КБ 1 9
# Кравченя Леонид ПМ 1 4
# Кошкин Владимир ИН 1 7
# Липин Федор ПИ 2 4
# Пенов Николай ПМ 1 5
# Кашин Петр КБ 4 8
